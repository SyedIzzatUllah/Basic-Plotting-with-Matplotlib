# %% [markdown]
# <a href="https://colab.research.google.com/github/SyedIzzatUllah/Basic-Plotting-with-Matplotlib/blob/main/Basic_Plotting_with_Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Basic Plotting with Matplotlib**
#
# *Intro to pyplot*
#
# matplotlib.pyplot is a collection of functions that make matplotlib work like MATLAB. Each pyplot function makes some change to a figure: e.g., creates a figure, creates a plotting area in a figure, plots some lines in a plotting area, decorates the plot with labels, etc.

# %% [markdown]
# Generating visualizations with pyplot is very quick:

# %%
import matplotlib.pyplot as plt
plt.plot([1, 2, 3, 4,5,6])
plt.xlabel('Numbers Visu')
plt.show()

# %%
plt.plot([1, 2, 6, 4], [1, 4, 9, 18])

# %% [markdown]
# **Formatting the style of your plot**
#
# For every x, y pair of arguments, there is an optional third argument which is the format string that indicates the color and line type of the plot. The letters and symbols of the format string are from MATLAB, and you concatenate a color string with a line style string.

# %%
plt.plot([1, 2, 3], [4, 9, 16], 'ro')
plt.axis([0, 6, 0, 18])
plt.show()

# %% [markdown]
# If matplotlib were limited to working with lists, it would be fairly useless for numeric processing. Generally, you will use numpy arrays. In fact, all sequences are converted to numpy arrays internally. The example below illustrates plotting several lines with different format styles in one function call using arrays.

# %%
import numpy as np #import numpy 

# evenly sampled time at 200ms intervals
t = np.arange(0., 5., 0.2)

# red dashes, blue squares and green triangles
plt.plot(t, t, 'y--', t, t**2, 'bs', t, t**3, 'g^')
plt.show()

# %% [markdown]
# **Plotting with keyword strings**
#
# There are some instances where you have data in a format that lets you access particular variables with strings. For example, with numpy.recarray or pandas.DataFrame.

# %%
data = {'a': np.arange(50),
        'c': np.random.randint(0, 60, 50),
        'd': np.random.randn(50)}
data['b'] = data['a'] + 10 * np.random.randn(50)
data['d'] = np.abs(data['d']) * 100

plt.scatter('a', 'b', c='c', s='d', data=data)
plt.xlabel('Entry X')
plt.ylabel('Entry Y')
plt.show()

# %% [markdown]
# **Plotting with categorical variables**
#
# It is also possible to create a plot using categorical variables. Matplotlib allows you to pass categorical variables directly to many plotting functions. For example:

# %%
names = ['group_Syed', 'group_Ayaan', 'group_Saad']
values = [10, 23, 45]

plt.figure(figsize=(13, 5))

plt.subplot(131)
plt.bar(names, values)
plt.subplot(132)
plt.scatter(names, values)
plt.subplot(133)
plt.plot(names, values)
plt.suptitle('Categorical Plotting in Pyplot')
plt.show()

# %% [markdown]
# That's it from Pyplot, if you are curious about do visit **(https://matplotlib.org/stable/tutorials/introductory/pyplot.html)** for more.

# %%
print("Thank You!")
# Out:
# Thank You!
